# %%
# Importing necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# Loading the dataset
dataset = pd.read_csv("insurance_pre.csv")
dataset.head()
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
# Categorical data - One-Hot encodinng
dataset = pd.get_dummies(dataset,drop_first=True,dtype=int)
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400         0           1
# 1   18  33.770         1   1725.55230         1           0
# 2   28  33.000         3   4449.46200         1           0
# 3   33  22.705         0  21984.47061         1           0
# 4   32  28.880         0   3866.85520         1           0

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
# Feature selection
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent.head()
# Out:
#    age     bmi  children  sex_male  smoker_yes
# 0   19  27.900         0         0           1
# 1   18  33.770         1         1           0
# 2   28  33.000         3         1           0
# 3   33  22.705         0         1           0
# 4   32  28.880         0         1           0

# %%
# Target or output
dependent = dataset[['charges']]
dependent.head()
# Out:
#        charges
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520

# %%
# Training and testing data
X_train,X_test,Y_train,Y_test = train_test_split(independent,dependent,test_size=0.3,random_state=0)

# %%
# Data standardization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
scy = StandardScaler()
Y_train = scy.fit_transform(Y_train)
Y_test = scy.transform(Y_test)

# %%
# Model training
from sklearn.svm import SVR
regressor = SVR(kernel='poly',C=1000,gamma='scale')
regressor.fit(X_train,Y_train)
# Out:
# C:\Users\thiru\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=1000, kernel='poly')

# %%
regressor.intercept_
# Out:
# array([-0.36612185])

# %%
regressor.n_support_
# Out:
# array([330], dtype=int32)

# %%
regressor.support_vectors_
# Out:
# array([[-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [-1.46169465,  0.27881295, -0.89833872, -0.97676557,  1.98149332],
#        [ 0.10916367,  0.85484838, -0.06746417, -0.97676557, -0.50466988],
#        ...,
#        [-1.5330973 , -1.47416395, -0.89833872,  1.02378711,  1.98149332],
#        [ 0.18056632,  0.83719827,  0.76341038,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]],
#       shape=(330, 5))

# %%
# Model prediction
Y_pred = regressor.predict(X_test)
Y_pred
# Out:
# array([-2.17561723e-01, -3.23303433e-01,  2.87684664e+00,  1.38727432e-02,
#        -9.81068886e-02, -6.60442214e-01, -1.03085129e+00, -9.25198043e-02,
#        -4.30366650e-01, -6.08837395e-01, -4.68341712e-01, -2.26452392e-01,
#        -4.08843128e-01, -6.28051920e-01,  1.00116914e+00, -1.75835138e-01,
#        -7.48640521e-02, -7.82035020e-01, -5.06335405e-01,  1.04461587e+00,
#         1.06120880e+00, -3.30231896e-02, -2.47264298e-01,  1.43049177e+00,
#        -8.95354698e-01, -6.43795157e-01, -5.63654143e-01, -3.71295307e-01,
#        -6.89202385e-01, -3.39642422e-01, -3.93884520e-01,  3.34517355e+00,
#         4.59940188e-02, -1.81260212e-01, -7.03924475e-02, -7.22868460e-01,
#        -3.11521471e-01,  2.00265078e+00,  2.01824632e+00, -9.32960125e-01,
#        -4.61169362e-01, -8.08095988e-01,  1.07190413e+00,  2.78967577e+00,
#         1.91921484e+00, -8.43903306e-01, -1.77682413e-01, -4.65257930e-01,
# ...

# %%
# Model evaluation
R2_score = r2_score(Y_test,Y_pred)
R2_score
# Out:
# 0.8689312974410522

# %%
# User inputs
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=float(input("Sex Male 0 or 1:"))
smoker_yes_input=float(input("Smoker yes 0 or 1:"))

# %%
scaled_user_input = sc.transform([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
scaled_user_input
# Out:
# C:\Users\thiru\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.31888935, -1.40436578, -0.06746417, -0.97676557, -0.50466988]])

# %%
result = regressor.predict(scaled_user_input)
result
# Out:
# array([-0.90097884])

# %%
scaled_Output = scy.inverse_transform([result])
scaled_Output
# Out:
# array([[2534.9078319]])

# %%
import pickle
filename = "SVR_PreProcessed_Input_Output_Saved_Model.sav"
pickle.dump(regressor,open(filename,'wb'))
